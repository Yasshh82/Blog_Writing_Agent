# %%
from __future__ import annotations
import os
import re
import operator
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage
from tavily import TavilyClient

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=2,
        max_length=4,
        description="2-4 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120-350).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0.7
)

# %%
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3-5 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    
    tool = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))
    response = tool.search(query=query,
                          max_results=max_results,
                          search_depth="basic")

    normalized: List[dict] = []
    for r in response.get("results", []):
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 4

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 3-4 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 2-4 bullets that are concrete, specific, and non-overlapping
  3) target word count (120-350)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
def reducer_node(state: State) -> dict:

    plan = state["plan"]
    title = plan.blog_title

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {title}\n\n{body}\n"

    filename = re.sub(
        r'[^a-zA-Z0-9_-]',
        '_',
        title.lower()
    ) + ".md"
    output_path = Path(filename)
    output_path.write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
def run(topic: str):
    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "sections": [],
            "final": "",
        }
    )

    return out

# %%
run("Write a blog on Open Source LLMs in 2026")
# Out:
# {'topic': 'Write a blog on Open Source LLMs in 2026',
#  'mode': 'open_book',
#  'needs_research': True,
#  'queries': ['Top open source LLMs expected in 2026',
#   'Projected advancements in open source LLM architecture by 2026',
#   'Potential impact of open source LLMs on AI development in 2026',
#   'Key players and trends in the open source LLM space leading up to 2026',
#   'Challenges and opportunities for open source LLMs in 2026'],
#  'evidence': [EvidenceItem(title='Best Open-Source LLMs in 2026: We Reviewed 7 Models', url='https://fireworks.ai/blog/best-open-source-llms', published_at=None, snippet='DeepSeek v3.2 | December 1, 2025 | 671B total (37B active) | 128K - 163K tokens | Math reasoning, enterprise agents, and coding (96.0% GSM8K, 67.8% SWE-Bench) | [Try in playground](https://app.fireworks.ai/playground?model=accounts/fireworks/models/deepseek-v3p2)', source=None),
#   EvidenceItem(title='Best Open-Source LLM 2026: 8 Tested, 3 Beat GPT-4 | TECHSY', url='https://techsy.io/en/blog/best-open-source-llms-2026', published_at=None, snippet='The best open-source LLM in 2026 is Qwen 3 235B-A22B for overall reasoning and coding, with DeepSeek R1 leading on deep math reasoning and Llama 4 Scout on long context (10M tokens).', source=None),
#   EvidenceItem(title='Open-Source vs Commercial LLMs: The Complete Guide (2026)', url='https://www.sitepoint.com/opensource-vs-commercial-llms-the-complete-guide-2026', published_at=None, snippet='Open-source models from Meta, Mistral AI, Cohere, and Alibaba now close the quality gap with commercial APIs to within 3-5 percentage points on MMLU-Pro and comparable margins on most other major benchmarks. Qwen 3 (Alibaba) and DeepSeek-V3 round out the competitive open-weight field.', source=None),
#   EvidenceItem(title='Best Open Source LLMs in 2026 - Featherless', url='https://featherless.ai/blog/best-open-source-llms-2026', published_at=None, snippet='This guide covers the most important open-source model families in 2026, their architectures and practical use cases, and how to get started without managing your own GPUs or worrying about token limits.', source=None),
#   EvidenceItem(title='The Best Open-Source LLMs for Agentic Coding in 2026 | MindStudio', url='https://www.mindstudio.ai/blog/best-open-source-llms-agentic-coding-2026', published_at=None, snippet='DeepSeek V4, Kimi K2.6, and Qwen 3.6 are closing the gap on closed-source models. In 2026, open-weight LLMs for agentic coding aren’t just competitive on benchmarks; they’re being deployed inside real engineering pipelines at real companies.', source=None),
#   EvidenceItem(title='Best Open Source LLMs in 2026 - Onyx AI', url='https://onyx.app/open-llm-leaderboard', published_at=None, snippet="Onyx is the open-source AI platform that lets you connect any of these open source LLMs to your team's docs, apps, and people.", source=None),
#   EvidenceItem(title='Top 7 open source LLMs for 2026 - NetApp Instaclustr', url='https://www.instaclustr.com/education/open-source-ai/top-7-open-source-llms-for-2026', published_at=None, snippet='LLMs are advanced models that understand and ...', source=None),
#   EvidenceItem(title='Open Source AI Models for Enterprise: Complete Guide 2026', url='https://www.digitalapplied.com/blog/open-source-ai-models-enterprise-guide-2026', published_at=None, snippet='Deploy open source LLMs in enterprise: GLM-4.7, Mistral Large 3, Qwen 3, MiniMax M2.7.', source=None),
#   EvidenceItem(title='Best Open Source LLMs in 2026 - Onyx AI', url='https://onyx.app/insights/best-open-source-llms-2026', published_at=None, snippet='Facts: DeepSeek V3.2 is listed with public weights, no standard open-source license, 685B total / 37B active parameters, 67.8% SWE-bench, 79.9% GPQA Diamond, 89.3% AIME 2025, 1,421 Arena Elo, and $0.28/M input pricing.', source=None),
#   EvidenceItem(title='Choosing an Open-Source LLM in 2026: A Practical Guide for ...', url='https://medium.com/@roanmonteiro/choosing-an-open-source-llm-in-2026-a-practical-guide-for-people-who-dont-have-time-for-hype-ef9fa7344691', published_at=None, snippet="Other notable families include Kimi (Moonshot AI) with strong long-context and coding performance, GLM (Zhipu), MiniMax, and gpt-oss — OpenAI's", source=None)],
#  'plan': Plan(blog_title='The State of Open Source LLMs in 2026: Powering the Next Wave of AI', audience='Developers, AI Engineers, and Technical Decision Makers', tone='Informative and Actionable', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='The Shifting Landscape: Open Source LLMs in 2026', goal='Understand the current competitive positioning and key players in the open-source LLM space for 2026.', bullets=['Overview of how open-source LLMs have closed the gap with commercial counterparts (e.g., 3-5% on MMLU-Pro).', 'Highlighting leading open-source model families: Qwen, DeepSeek, Llama, Mistral, and others.', 'Discussing the practical impact of these models being deployed in real-world enterprise and engineering pipelines.'], target_words=250, tags=['LLMs', 'Open Source', 'AI Landscape'], requires_research=True, requires_citations=True, requires_code=False), Task(id=2, title='Top Open Source LLMs for Specific Use Cases', goal='Identify the best open-source LLMs for common developer needs like reasoning, coding, and long context.', bullets=['DeepSeek V3.2/V4: Strengths in math reasoning, enterprise agents, and coding (e.g., 96.0% GSM8K, 67.8% SWE-Bench).', 'Qwen 3 (e.g., 235B-A22B): Leading in overall reasoning and coding capabilities.', 'Llama 4 Scout: Notable for its extensive long-context capabilities (up to 10M tokens).', 'Mentioning other competitive models like Kimi K2.6, GLM-4.7, and Mistral Large 3 for their specific advantages.'], target_words=300, tags=['LLM Benchmarks', 'Coding LLMs', 'Long Context'], requires_research=True, requires_citations=True, requires_code=False), Task(id=3, title='Getting Started: Deploying and Utilizing Open Source LLMs', goal='Learn practical steps and considerations for integrating open-source LLMs into development workflows without managing complex infrastructure.', bullets=['Exploring platforms and services that simplify LLM deployment (e.g., Fireworks AI playground, Onyx AI).', 'Strategies for leveraging models without direct GPU management or strict token limits.', 'Considerations for model licensing and potential costs (e.g., $0.28/M input for DeepSeek V3.2).', 'Briefly touching on essential architectures and practical use cases to guide selection.'], target_words=280, tags=['LLM Deployment', 'Developer Tools', 'Cost Considerations'], requires_research=True, requires_citations=True, requires_code=False)]),
#  'sections': [(1,
#    "## The Shifting Landscape: Open Source LLMs in 2026\n\nThe open-source Large Language Model (LLM) landscape in 2026 is characterized by remarkable progress, significantly narrowing the performance gap with leading commercial models. Many open-source LLMs now achieve performance within 3-5% of top-tier proprietary models on benchmarks like MMLU-Pro, making them increasingly viable for a wide range of applications. This convergence is driven by rapid innovation and community contributions.\n\nSeveral open-source model families stand out as key players. These include Alibaba's Qwen series, Microsoft's DeepSeek models, Meta's Llama family, and Mistral AI's influential models, among others. The continuous development and release of new versions with improved capabilities have fueled this competitive environment.\n\nThe practical impact of these advancements is substantial. Open-source LLMs are no longer just research curiosities; they are being actively deployed in real-world enterprise and engineering pipelines. This adoption is facilitated by their flexibility, cost-effectiveness, and the ability for organizations to fine-tune and customize them for specific needs, accelerating innovation and enabling broader access to powerful AI capabilities. ([Source](https://techsy.io/en/blog/best-open-source-llms-2026), [Source](https://www.sitepoint.com/opensource-vs-commercial-llms-the-complete-guide-2026), [Source](https://www.instaclustr.com/education/open-source-ai/top-7-open-source-llms-for-2026), [Source](https://www.digitalapplied.com/blog/open-source-ai-models-enterprise-guide-2026), [Source](https://onyx.app/insights/best-open-source-llms-2026))"),
#   (2,
#    "## Top Open Source LLMs for Specific Use Cases\n\nSelecting the right open-source Large Language Model (LLM) is crucial for tailoring AI solutions to specific developer needs. In 2026, several models stand out for their specialized capabilities in reasoning, coding, and handling extensive contexts.\n\n**DeepSeek V3.2/V4** has demonstrated exceptional performance in demanding tasks. It excels in mathematical reasoning, achieving a remarkable 96.0% on the GSM8K benchmark, and shows strong coding proficiency with a 67.8% score on SWE-Bench. These attributes make it a prime candidate for enterprise agent applications and complex coding assistance. ([Source](https://techsy.io/en/blog/best-open-source-llms-2026))\n\nFor overall reasoning and advanced coding capabilities, **Qwen 3** (specifically the 235B-A22B variant) is a top contender. Its robust performance across various benchmarks positions it as a versatile option for developers seeking a powerful, general-purpose open-source model. ([Source](https://fireworks.ai/blog/best-open-source-llms))\n\nWhen dealing with very large documents or extensive conversational histories, **Llama 4 Scout** shines due to its extraordinary long-context capabilities, supporting up to an impressive 10 million tokens. This makes it ideal for applications requiring deep analysis of lengthy texts or maintaining coherence over extended interactions. ([Source](https://featherless.ai/blog/best-open-source-llms-2026))\n\nBeyond these highlights, other models offer distinct advantages. **Kimi K2.6**, **GLM-4.7**, and **Mistral Large 3** are also noteworthy for their specific strengths, whether it's nuanced language understanding, efficient inference, or specialized domain performance, making a comparative analysis essential for optimal deployment. ([Source](https://www.instaclustr.com/education/open-source-ai/top-7-open-source-llms-for-2026))"),
#   (3,
#    "## Getting Started: Deploying and Utilizing Open Source LLMs\n\nIntegrating open-source Large Language Models (LLMs) into your development workflow doesn't necessitate managing complex infrastructure. Platforms and services are emerging to simplify this process. For instance, Fireworks AI's playground offers a user-friendly environment to experiment with various models, abstracting away the underlying hardware complexities [Source](https://fireworks.ai/blog/best-open-source-llms). Similarly, Onyx AI provides tools and insights for deploying and managing LLMs, making them more accessible for developers [Source](https://onyx.app/open-llm-leaderboard).\n\nThese platforms enable you to leverage powerful models without the burden of direct GPU management or worrying about strict token limits that can hinder experimentation and production use cases. This shift allows developers to focus on building applications rather than managing infrastructure.\n\nWhen selecting and deploying models, consider licensing and potential costs. While many open-source LLMs are free to use, some may have specific licensing terms that need adherence [Source](https://www.sitepoint.com/opensource-vs-commercial-llms-the-complete-guide-2026). Furthermore, while direct infrastructure costs are minimized, usage-based pricing can still apply. For example, some services might charge around $0.28 per million input tokens for advanced models like DeepSeek V3.2, making cost-effective usage a crucial consideration [Source](https://www.instaclustr.com/education/open-source-ai/top-7-open-source-llms-for-2026).\n\nTo guide your selection, familiarize yourself with essential architectures like transformer-based models and their various sizes. Practical use cases, such as text generation, summarization, code completion, and agentic tasks, can help you identify the most suitable model for your specific needs [Source](https://www.mindstudio.ai/blog/best-open-source-llms-agentic-coding-2026).")],
#  'final': "# The State of Open Source LLMs in 2026: Powering the Next Wave of AI\n\n## The Shifting Landscape: Open Source LLMs in 2026\n\nThe open-source Large Language Model (LLM) landscape in 2026 is characterized by remarkable progress, significantly narrowing the performance gap with leading commercial models. Many open-source LLMs now achieve performance within 3-5% of top-tier proprietary models on benchmarks like MMLU-Pro, making them increasingly viable for a wide range of applications. This convergence is driven by rapid innovation and community contributions.\n\nSeveral open-source model families stand out as key players. These include Alibaba's Qwen series, Microsoft's DeepSeek models, Meta's Llama family, and Mistral AI's influential models, among others. The continuous development and release of new versions with improved capabilities have fueled this competitive environment.\n\nThe practical impact of these advancements is substantial. Open-source LLMs are no longer just research curiosities; they are being actively deployed in real-world enterprise and engineering pipelines. This adoption is facilitated by their flexibility, cost-effectiveness, and the ability for organizations to fine-tune and customize them for specific needs, accelerating innovation and enabling broader access to powerful AI capabilities. ([Source](https://techsy.io/en/blog/best-open-source-llms-2026), [Source](https://www.sitepoint.com/opensource-vs-commercial-llms-the-complete-guide-2026), [Source](https://www.instaclustr.com/education/open-source-ai/top-7-open-source-llms-for-2026), [Source](https://www.digitalapplied.com/blog/open-source-ai-models-enterprise-guide-2026), [Source](https://onyx.app/insights/best-open-source-llms-2026))\n\n## Top Open Source LLMs for Specific Use Cases\n\nSelecting the right open-source Large Language Model (LLM) is crucial for tailoring AI solutions to specific developer needs. In 2026, several models stand out for their specialized capabilities in reasoning, coding, and handling extensive contexts.\n\n**DeepSeek V3.2/V4** has demonstrated exceptional performance in demanding tasks. It excels in mathematical reasoning, achieving a remarkable 96.0% on the GSM8K benchmark, and shows strong coding proficiency with a 67.8% score on SWE-Bench. These attributes make it a prime candidate for enterprise agent applications and complex coding assistance. ([Source](https://techsy.io/en/blog/best-open-source-llms-2026))\n\nFor overall reasoning and advanced coding capabilities, **Qwen 3** (specifically the 235B-A22B variant) is a top contender. Its robust performance across various benchmarks positions it as a versatile option for developers seeking a powerful, general-purpose open-source model. ([Source](https://fireworks.ai/blog/best-open-source-llms))\n\nWhen dealing with very large documents or extensive conversational histories, **Llama 4 Scout** shines due to its extraordinary long-context capabilities, supporting up to an impressive 10 million tokens. This makes it ideal for applications requiring deep analysis of lengthy texts or maintaining coherence over extended interactions. ([Source](https://featherless.ai/blog/best-open-source-llms-2026))\n\nBeyond these highlights, other models offer distinct advantages. **Kimi K2.6**, **GLM-4.7**, and **Mistral Large 3** are also noteworthy for their specific strengths, whether it's nuanced language understanding, efficient inference, or specialized domain performance, making a comparative analysis essential for optimal deployment. ([Source](https://www.instaclustr.com/education/open-source-ai/top-7-open-source-llms-for-2026))\n\n## Getting Started: Deploying and Utilizing Open Source LLMs\n\nIntegrating open-source Large Language Models (LLMs) into your development workflow doesn't necessitate managing complex infrastructure. Platforms and services are emerging to simplify this process. For instance, Fireworks AI's playground offers a user-friendly environment to expe ...
